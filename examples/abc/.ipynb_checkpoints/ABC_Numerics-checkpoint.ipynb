# %% [markdown]
# # Numerical Results for the A+B→C Network

# %% [markdown]
# ### Compare Gillespie simulation with mass action kinetics and Plefka approximation

# %%
using Pkg
cd(@__DIR__)
Pkg.activate("../../")
using CRN
using PyPlot
PyPlot.PyDict(PyPlot.matplotlib."rcParams")["font.size"] = 16
# Out:
#  Activating environment at `~/ownCloud/Master/Simulations/CRN/Project.toml`
# ┌ Info: Precompiling CRN [da75a55d-9cc8-480a-9f60-a17664246748]
# └ @ Base loading.jl:1260
# 16

# %%
# Parameters
num_species = 3     # number of species
num_int = 1         # number of interaction reaction

# Reaction constants
k1 = [8, 8, 3]      # Creation
k2 = [3, 2, 1.5]    # Annihiliation
k3 = [0.5]          # Interaction
k = [k1, k2, k3]

# Stoichiometric
s_i = zeros(Int, num_int, num_species)
r_i = copy(s_i)
s_i[1,:] = [0 0 1]
r_i[1,:] = [1 1 0]

# Times
t_init = 0.0        # Start time
t_final = 5.0       # End time
delta_t = 0.01       # time step
tspan = collect(t_init:delta_t:t_final)

# Initial condition
x0 = k1 ./ k2
# Out:
# 3-element Array{Float64,1}:
#  2.6666666666666665
#  4.0
#  2.0

# %% [markdown]
# ## Gillespie Simulation

# %%
N = 10000   # Repititions
res_gil = gillespie_avg(x0, k, s_i, r_i, tspan, N)
plot_trajectories(res_gil)
# Out:
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# PyObject Text(32.999999999999986, 0.5, 'Copy Numbers')

# %% [markdown]
# ## Mass Action Kinetics

# %%
function f_massAction!(du,u,k,t)
    du[1] = k1[1] - k2[1]*u[1] - k3[1]*u[1]*u[2]
    du[2] = k1[2] - k2[2]*u[2] - k3[1]*u[1]*u[2]
    du[3] = k1[3] - k2[3]*u[3] + k3[1]*u[1]*u[2]
end

ts = (tspan[1], tspan[end])
res_ma = ode_solver(f_massAction!, k, ts, delta_t, x0)
plot_trajectories_and_deviation(res_ma, res_gil)
# Out:
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# PyObject Text(850.2045454545454, 0.5, 'Relative deviation from reference')

# %% [markdown]
# ## Plefka with linear O.P. and power α¹

# %%
plf_sim_11 = Plefka(1.0, 1, "linear") # α, alphaOrder, orderParameter
res_plf_11 = euler_step(x0, k, tspan, plf_sim_11, s_i, r_i)
plot_trajectories_and_deviation(res_plf_11[1], res_gil)
plot_hatTheta(tspan, res_plf_11[3])
plot_responses(res_plf_11[2])
# Out:
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)

# %% [markdown]
# ## Plefka with linear O.P. and power α²

# %%
plf_sim_21 = Plefka(1.0, 2, "linear") # α, alphaOrder, orderParameter
res_plf_21 = euler_step(x0, k, tspan, plf_sim_21, s_i, r_i)
plot_trajectories_and_deviation(res_plf_21[1], res_gil)
plot_hatTheta(tspan, res_plf_21[3])
plot_responses(res_plf_21[2])
# Out:
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)

# %% [markdown]
# ## Plefka with quad O.P. and power α¹

# %%
plf_sim_12 = Plefka(1.0, 1, "quad") # α, alphaOrder, orderParameter
res_plf_12 = euler_step(x0, k, tspan, plf_sim_12, s_i, r_i)
plot_trajectories_and_deviation(res_plf_12[1], res_gil)
plot_hatTheta(tspan, res_plf_12[3])
plot_responses(res_plf_12[2])
plot_hatR_diag(tspan, res_plf_12[3])
# Out:
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# PyObject Text(43.17777777777776, 0.5, '$\\hat{R}_1(\\tau,\\tau_-)\\,\\Delta t$')

# %% [markdown]
# ## Plefka with quad O.P. and power α²

# %%
plf_sim_22 = Plefka(1.0, 2, "quad") # α, alphaOrder, orderParameter
res_plf_22 = euler_step(x0, k, tspan, plf_sim_22, s_i, r_i)
plot_trajectories_and_deviation(res_plf_22[1], res_gil)
plot_hatTheta(tspan, res_plf_12[3])
plot_responses(res_plf_12[2])
plot_hatR_diag(tspan, res_plf_12[3])
plot_hatR(tspan, res_plf_22[3])
# Out:
# Figure(PyObject <Figure size 2000x500 with 2 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)

# %%
function plot_k3eff(res, resp, Theta2, k3)
    y = res.data
    k3eff = zeros(size(y,2))
    for t in 1:size(y,2)
        integral = sum(y[1,1:t].*y[2,1:t].*resp[1,t,1:t].*resp[2,t,1:t])
        k3eff[t] = k3 - k3^2*integral/(y[1,t]*y[2,t])
    end
    Theta_eff = k3 .- k3^2*Theta2./(y[1,:]*y[2,:])
    figure(figsize=(20,5))
    plot(res.time, k3eff, label="k3 eff")
    plot([res.time[1], res.time[end]], [k3, k3], label="k3 const")
    plot(res.time[1:end-1], Theta_eff[1:end-1], label="Theta 2")
    legend()
    xlabel("Time")
    ylabel("Reaction constant")
end
plot_k3eff(res_plf_21[1], res_plf_21[2].data, res_plf_21[3].hatTheta2[1,:], k3[1])
# Out:
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# PyObject Text(33.000000000000014, 0.5, 'Reaction constant')

# %%
#hatR1 = Responses(tspan, res_plf_22[3].hatR1)
hatR2 = Responses(tspan, res_plf_22[3].hatR2)
#plot_responses_timeslice(res_plf_22[2], 6.)
plot_responses_timeslice(hatR2, 4.99)
# Out:
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# PyObject Text(35.199999999999974, 0.5, '$ R(\\tau=4.99,\\tau^\\prime) $')

# %%
plot_deviation(res_plf_21[1], res_gil)
plot_deviation(res_plf_22[1], res_gil)
plot_deviation(res_plf_21[1], res_plf_22[1])
# Out:
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# Figure(PyObject <Figure size 2000x500 with 1 Axes>)
# PyObject Text(32.999999999999986, 0.5, 'Relative deviation from reference')

# %%
idx_species = 1
title = ["GIL" "lin-1" "quad-1" "lin-2" "quad-2"]
[ title; res_gil.data[idx_species,:] res_plf_11[1].data[idx_species,:] res_plf_12[1].data[idx_species,:] res_plf_21[1].data[idx_species,:] res_plf_22[1].data[idx_species,:] ]
# Out:
# 502×5 Array{Any,2}:
#   "GIL"   "lin-1"   "quad-1"   "lin-2"   "quad-2"
#  2.6875  2.66667   2.66667    2.66667   2.66667
#  2.6372  2.61333   2.66667    2.6136    2.66693
#  2.5852  2.56336   2.61333    2.56412   2.61411
#  2.5378  2.51653   2.56231    2.51798   2.5638
#  2.495   2.47261   2.51454    2.47491   2.51692
#  2.4522  2.43141   2.46982    2.43471   2.47323
#  2.4159  2.39276   2.42793    2.39716   2.4325
#  2.3789  2.35649   2.38869    2.36208   2.39451
#  2.346   2.32243   2.35192    2.32929   2.35906
#  2.3159  2.29046   2.31744    2.29864   2.32598
#  2.2884  2.26042   2.28512    2.26998   2.29509
#  2.2615  2.23221   2.2548     2.24318   2.26624
#  ⋮
#  1.867   1.82971   1.82971    1.87593   1.88817
#  1.8634  1.82971   1.82971    1.87593   1.88818
#  1.8644  1.82971   1.82971    1.87593   1.88818
#  1.8569  1.82971   1.82971    1.87593   1.88818
#  1.8552  1.82971   1.82971    1.87593   1.88818
#  1.8594  1.82971   1.82971    1.87593   1.88818
#  1.8662  1.82971   1.82971    1.87593   1.88818
#  1.8643  1.82971   1.82971    1.87593   1.88818
#  1.8654  1.82971   1.82971    1.87593   1.88818
#  1.859   1.82971   1.82971    1.87593   1.88818
#  1.859   1.82971   1.82971    1.87593   1.88819
#  1.86    1.82971   1.82971    1.87593   1.88819

# %%
plot_responses(Responses(tspan, log.(res_plf_21[2].data .+ 1e-3)))
plot_responses(Responses(tspan, log.(res_plf_22[2].data .+ 1e-3)))
# Out:
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)
# Figure(PyObject <Figure size 2000x500 with 4 Axes>)
